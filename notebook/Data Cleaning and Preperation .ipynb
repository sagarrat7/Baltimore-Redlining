# %% [markdown]
# # Data Cleaning and Preperation

# %% [markdown]
# ### Importing the Data and Creating a Data Frame

# %% [markdown]
# The fields of each record are characteristics of a graded section indicated by the security grade map seen above. These fields have been transcribed and stored in a __comma separated value (csv)__ format.
#
# Using the pandas library, we can create a data frame from the csv. A __data frame__ is a table where every row represents a single unique object, called an __entity__, and every column represents characteristics of these objects, called __attributes__.

# %%
# loads the pandas library 
import pandas as pd

# creates data frame named df by reading in the Baltimore csv
df = pd.read_csv("AD_Data_BaltimoreProject.csv")
df.head(n=3)
# Out:
#                Form     State        City Security_Grade  Area_Number  \
# 0  NS FORM-8 6-1-37  Maryland  Baltimore               A            2
# 1  NS FORM-8 6-1-37  Maryland  Baltimore               A            1
# 2  NS FORM-8 6-1-37  Maryland  Baltimore              A             3
#
#   Terrain_Description                               Favorable_Influences  \
# 0             Rolling  Fairly new suburban area of homogeneous charac...
# 1         Undulating   Very nicely planned residential area of medium...
# 2             Rolling               Good residential area. Well planned.
#
#   Detrimental_Influences              INHABITANTS_Type  \
# 0                   None      Substantial Middle Class
# 1                   None  Executives, Professional Men
# 2       Distance to City  Executives, Professional Men
#
#   INHABITANTS_Annual_Income     ...     INHABITANTS_Population_Increase  \
# 0             $3000 - 5,000     ...                               Fast
# 1                over $5000     ...                     Moderately Fast
# 2               3500 - 7000     ...                     Moderately Fast
#
#    INHABITANTS_Population_Decrease INHABITANTS_Population_Static  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
#
#           BUILDINGS_Types   BUILDINGS_Construction  BUILDINGS_Age  \
# 0  Detached an row houses          Brick and frame  1 to 10 years
# 1  Single family detached          Brick and Stone       12 years
# 2     One family detached  Brick, Stone, and Frame  1 to 20 years
#
#     BUILDINGS_Repair Ten_Fifteen_Desirability  \
# 0               Good                   Upward
# 1          Very good                   Upward
# 2  Good to excellent                   Upward
#
#                                              Remarks        Date
# 0  A recent development with much room for expans...  May 4,1937
# 1  Mostly fee properties. A few homes valued at $...  May 4,1937
# 2  Principally fee property. This section lies in...  May 4,1937
#
# [3 rows x 26 columns]

# %% [markdown]
# After obtaining our data, we need to clean it to prepare for data analysis. This includes handling similiar text values and making sure a column of interest contains a single attribute.

# %% [markdown]
# ### Handling Text Values with Similar Meanings

# %% [markdown]
# The `INHABITANTS_Foreignborn` varaible indicates whether there are foreigners in a neighborhood section. Observe that different forms used 'No' or 'None' to indicate there are no foreigners and 'Small' , 'Very few' , and 'Mixture' are various ways of indicating there were foreigners. `NaN` indicates the value in the form is missing.

# %%
# selects rows with indices between 0 to 15 included of the 'INHABITANTS_Foreignborn' column
df.ix[0:15,'INHABITANTS_Foreignborn']
# Out:
# 0           No
# 1         None
# 2         None
# 3         None
# 4         None
# 5          NaN
# 6           No
# 7           No
# 8           No
# 9        Small
# 10    Very few
# 11          No
# 12          No
# 13          No
# 14          No
# 15     Mixture
# Name: INHABITANTS_Foreignborn, dtype: object

# %% [markdown]
# Since columns with categorized values are easier to analyze, we are going to transform this column to indicate whether there are foreigners or not. In Python, `None` is a special keyword that indicates the cell has a null value. Therefore, we will alter all the 'None' values to 'No' and every other value that indicates there are to 'Yes'.

# %%
# replaces the values of 'None' with 'No'
df['INHABITANTS_Foreignborn'] = df['INHABITANTS_Foreignborn'].replace('None', 'No')

# replaces all other values with 'Yes'
for value in df['INHABITANTS_Foreignborn']:
    if value != 'No' and value != 'NaN':
        df['INHABITANTS_Foreignborn'] = df['INHABITANTS_Foreignborn'].replace(value, 'Yes')

df.ix[0:15,'INHABITANTS_Foreignborn']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
# 5     Yes
# 6      No
# 7      No
# 8      No
# 9     Yes
# 10    Yes
# 11     No
# 12     No
# 13     No
# 14     No
# 15    Yes
# Name: INHABITANTS_Foreignborn, dtype: object

# %% [markdown]
# `Detrimental_Influences`  are descriptions of a region's undesiriable characteristics. Notice in this case that there are multiple variations of the meaning of 'No' to be replaced.

# %%
df.ix[0:15,'Detrimental_Influences']
# Out:
# 0                                          None
# 1                                          None
# 2                              Distance to City
# 3                                          None
# 4                                          None
# 5                                           NaN
# 6                                           No.
# 7                                          None
# 8     Few streets of property in poor condition
# 9                                          None
# 10                                         None
# 11                      Built on filled ground.
# 12                                         None
# 13                                         None
# 14                   Distance to center of city
# 15                                         None
# Name: Detrimental_Influences, dtype: object

# %% [markdown]
# To handle the multiple words to be replaced we can use an __array__, a list that holds a fixed number of values of the same type, to store several strings. Then we can replace each occurence in `Detrimental_Influences` by iterating through the array and using the `replace()` function.

# %%
# declares an array called 'no_words' containing strings that all mean 'No'
no_words = ['No.','no', 'none', 'None']

# interates through no_words and replaces each occurence in Detrimental_Influences
for word in no_words:
    df['Detrimental_Influences'] = df['Detrimental_Influences'].replace( word , 'No')

# %%
df.ix[0:15,'Detrimental_Influences']
# Out:
# 0                                            No
# 1                                            No
# 2                              Distance to City
# 3                                            No
# 4                                            No
# 5                                           NaN
# 6                                            No
# 7                                            No
# 8     Few streets of property in poor condition
# 9                                            No
# 10                                           No
# 11                      Built on filled ground.
# 12                                           No
# 13                                           No
# 14                   Distance to center of city
# 15                                           No
# Name: Detrimental_Influences, dtype: object

# %% [markdown]
# We need to do these same operations for `INHABITANTS_Negro`, whether residents are African American, and `INHABITANTS_Infiltration`, which refers to if the area is being infiltrated. __Functions__ are procedures that perform specific tasks. In Python, we can create our own functions or used built-in functions such as `replace()`. __Parameters__ are variables that are defined in the function definition. __Arguments__ are the values passed into a function.
#
# The `replace_values` function has three parmeters : `attribute`, `new_word`, and `words_to_replace`.

# %%
# this function iterates through an array of words to be replaced and replaces each occurence in the attribute 
# with the new word
def replace_values(attribute, new_word, words_to_replace):
    for word in words_to_replace:
        df[attribute] = df[attribute].replace(word, new_word) 


replace_values('INHABITANTS_Negro', 'No', no_words)
replace_values('INHABITANTS_Infiltration', 'No', no_words)

# %%
df.ix[0:15,'INHABITANTS_Infiltration']
# Out:
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# 5                 NaN
# 6                  No
# 7                  No
# 8                  No
# 9                 NaN
# 10                 No
# 11                 No
# 12                 No
# 13                 No
# 14                 No
# 15    People from C-1
# Name: INHABITANTS_Infiltration, dtype: object

# %% [markdown]
# Note that we do the same procedure for words meaning 'few', however we could have made these columns have two categories, 'yes' or 'no', and indicate in our data analysis the alterations to our data.

# %%
# Various words meaning small 
small_words = ['Nominal','nominal', 'Small','small','Minimum', 'minimum','minimal', 'Very few']

replace_values('INHABITANTS_Negro', 'Few', small_words)
replace_values('INHABITANTS_Infiltration', 'Few', small_words)

# %%
df.ix[0:15,'INHABITANTS_Infiltration']
# Out:
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# 5                 NaN
# 6                  No
# 7                  No
# 8                  No
# 9                 NaN
# 10                 No
# 11                 No
# 12                 No
# 13                 No
# 14                 No
# 15    People from C-1
# Name: INHABITANTS_Infiltration, dtype: object

# %%
df.ix[0:15,'INHABITANTS_Negro']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
# 5     NaN
# 6      No
# 7      No
# 8      No
# 9      No
# 10     No
# 11     No
# 12     No
# 13     No
# 14     No
# 15     No
# Name: INHABITANTS_Negro, dtype: object

# %% [markdown]
# We can clean up the values of `INHABITANTS_Population_Increase`, how the population is increasing in an area, by choosing standard categories for the rate the population.

# %%
 df.ix[0:15,'INHABITANTS_Population_Increase']
# Out:
# 0               Fast
# 1     Moderately Fast
# 2     Moderately Fast
# 3              Slowly
# 4     Moderately Fast
# 5                 NaN
# 6                 NaN
# 7              Slowly
# 8     Moderately Fast
# 9     Moderately Fast
# 10                NaN
# 11             Slowly
# 12             Slowly
# 13         Moderately
# 14             Slowly
# 15              Fast
# Name: INHABITANTS_Population_Increase, dtype: object

# %% [markdown]
# We will define rates of the population as very slowly, slowly, moderately, moderately fast, fast based on the data.

# %%
# defines values to replace in the table 
very_slowly = ['Very Slowly', 'very slowly', 'very Slowly']
slowly = ['slowly', 'fairly slowly']
moderately = ['moderately']
moderately_fast = ['Moderately Fast', 'moderately Fast', 'moderately fast']
fast = ['very fast', 'Very Fast', 'fast']

# applies function to obtain our new values 
replace_values('INHABITANTS_Population_Increase', 'Very slowly', very_slowly)
replace_values('INHABITANTS_Population_Increase', 'Slowly', slowly)
replace_values('INHABITANTS_Population_Increase', 'Moderately', moderately )
replace_values('INHABITANTS_Population_Increase', 'Moderately fast', moderately_fast)
replace_values('INHABITANTS_Population_Increase', 'Moderately fast', moderately_fast)
replace_values('INHABITANTS_Population_Increase', 'Fast', fast)

# %%
 df.ix[0:15,'INHABITANTS_Population_Increase']
# Out:
# 0               Fast
# 1     Moderately fast
# 2     Moderately fast
# 3              Slowly
# 4     Moderately fast
# 5                 NaN
# 6                 NaN
# 7              Slowly
# 8     Moderately fast
# 9     Moderately fast
# 10                NaN
# 11             Slowly
# 12             Slowly
# 13         Moderately
# 14             Slowly
# 15              Fast
# Name: INHABITANTS_Population_Increase, dtype: object

# %% [markdown]
# ### String Parsing to Extract Data

# %% [markdown]
# Some of the cities have corresponding suburbs followed by a dash. We can extract the suburbs and create a new column using  `str.split()`.

# %%
df.ix[16:30,'City']
# Out:
# 16                                Baltimore
# 17                       Baltimore - Dundalk
# 18                                 Baltimore
# 19                  Baltimore - Metropolitan
# 20                                 Baltimore
# 21                  Baltimore - Metropolitan
# 22                                 Baltimore
# 23                   Baltimore - Sub. Burton
# 24    Baltimore - Sub. Mt. Washington Summit
# 25                Baltimore - Sub. Villahove
# 26            Baltimore - Sub. Colonial Park
# 27        Baltimore - Sub. Linthicum Heights
# 28                                 Baltimore
# 29                                 Baltimore
# 30                                 Baltimore
# Name: City, dtype: object

# %% [markdown]
#  A new data frame seperate is created with two columns seperated based on `str.split`, where `n=1` indicates the string is split once. We create two new attributes in the original data frame, `City_clean` and `Suburb`. Then we drop the old `City` city column and rename our new `City` attribute.

# %%
# creates a new data frame that splits the values in the orginal data frame on the '-' character 
newdf = df["City"].str.split('-', n = 1, expand = True) 
newdf.head()

# creates two new columns 
df['City_clean'] = newdf[0]
df['Suburb'] = newdf[1]

# removes the old column
df.drop(["City"], axis = 1, inplace = True) 

# renames as 'City'
df.rename(index=str, columns={"City_clean": "City"});

# %%
df.ix[16:30,['Suburb']]
# Out:
#                          Suburb
# 16                         None
# 17                      Dundalk
# 18                         None
# 19                 Metropolitan
# 20                         None
# 21                 Metropolitan
# 22                         None
# 23                  Sub. Burton
# 24   Sub. Mt. Washington Summit
# 25               Sub. Villahove
# 26           Sub. Colonial Park
# 27       Sub. Linthicum Heights
# 28                         None
# 29                         None
# 30                         None

# %% [markdown]
# The `BUILDINGS_Age` attribute represents the range of the age of the buildings in a region. Notice the range is given is given as a string of text. For purpose of analysis, we would like to extract the upper end of the range and create a column of numeric values.

# %%
df.ix[0:15,'BUILDINGS_Age']
# Out:
# 0      1 to 10 years
# 1           12 years
# 2      1 to 20 years
# 3           10 years
# 4      1 to 20 years
# 5                NaN
# 6           25 years
# 7     15 to 25 years
# 8           15 years
# 9      5 to 25 years
# 10          20 years
# 11     5 to 10 years
# 12          10 years
# 13          25 years
# 14     1 to 20 years
# 15     6 to 25 years
# Name: BUILDINGS_Age, dtype: object

# %% [markdown]
# Observe that the numeric value at the end of the range is always the last number followed by the string `years`. We use specific string patterns called __regular expressions (regex)__ and `str.extract()` to create a new attribute called `max_building_age`.

# %%
df['max_building_age'] = df['BUILDINGS_Age'].str.extract('(\d+)(?!.*\d)', expand=True)

# %% [markdown]
# The regular expression in this example is `(\d+)(?!.*\d)` and was tested using [Pythex](https://pythex.org/), a regex editor. We could have imported `re` , Python's regular expression library, to perform the same task, however this notebook consistenly uses `str()` functions.

# %%
df.ix[0:15,['BUILDINGS_Age','max_building_age']]
# Out:
#      BUILDINGS_Age max_building_age
# 0    1 to 10 years               10
# 1         12 years               12
# 2    1 to 20 years               20
# 3         10 years               10
# 4    1 to 20 years               20
# 5              NaN              NaN
# 6         25 years               25
# 7   15 to 25 years               25
# 8         15 years               15
# 9    5 to 25 years               25
# 10        20 years               20
# 11   5 to 10 years               10
# 12        10 years               10
# 13        25 years               25
# 14   1 to 20 years               20
# 15   6 to 25 years               25

# %% [markdown]
# The `Date`, the date indicated on the form, has three attributes with the pattern given by **month day, year**. As previously stated, we would like to have a single attribute per column.

# %%
df.ix[0:3,['Date']]
# Out:
#          Date
# 0  May 4,1937
# 1  May 4,1937
# 2  May 4,1937
# 3  May 4,1937

# %% [markdown]
# We can seperate this column into three columns:  `Month`, `Day`, and `Year` using `str.extract()` and regex patterns
# `(\d\d\d\d)` to indicate four digit year, `(\d)` to indicate a single digit day, and ` [A-Z]\w{0,}` to indicate __aplhanumeric__ text to extract the month. Note that regex can also be used to reformat the date column.

# %%
# extracts the year 
df['Year'] = df['Date'].str.extract('(\d\d\d\d)', expand=True)

# extracts day  
df['Day'] = df['Date'].str.extract('(\d)', expand=True)

# extracts month 
df['Month'] = df['Date'].str.extract('([A-Z]\w{0,})', expand=True)

df.ix[0:3,['Date','Month','Day','Year']]
# Out:
#          Date Month Day  Year
# 0  May 4,1937   May   4  1937
# 1  May 4,1937   May   4  1937
# 2  May 4,1937   May   4  1937
# 3  May 4,1937   May   4  1937

# %% [markdown]
# Similar to `BUILDINGS_Age`, `INHABITANTS_Annual_Income`, the range of income of residents in a section, is a string of text and we would like to extract the numeric value at the end of the range.

# %%
df.ix[0:7,['INHABITANTS_Annual_Income']]
# Out:
#   INHABITANTS_Annual_Income
# 0             $3000 - 5,000
# 1                over $5000
# 2               3500 - 7000
# 3                over $5000
# 4          $3,500 - $10,000
# 5                       NaN
# 6                over $4000
# 7                over $5000

# %% [markdown]
# Observe that some values are located after '$', some inlcude '-', and others include ','.Since the pattern to extract the last numeric value varies, we use `str.replace()`, `str.extract`, and regex in a sequence of operations to create a new column `max_annual_income`.

# %%
# replaces anything that is not a digit or ',' with empty space
df['max_annual_income'] = df['INHABITANTS_Annual_Income'].str.replace('[^\d(,)]',' ')

# %%
df.ix[0:7,['max_annual_income']]
# Out:
#   max_annual_income
# 0      3000   5,000
# 1              5000
# 2       3500   7000
# 3              5000
# 4   3,500    10,000
# 5               NaN
# 6              4000
# 7              5000

# %% [markdown]
# We did not include the delimeter in the previous `str.replace()` operation because their positions would have been replaced by an empty space. Now we want to remove delimeters.

# %%
# removes delimeter by replacing ',' with ''
df['max_annual_income'] = df['max_annual_income'].str.replace('[(,)]','')

# %%
df.ix[0:7,['max_annual_income']]
# Out:
#   max_annual_income
# 0       3000   5000
# 1              5000
# 2       3500   7000
# 3              5000
# 4     3500    10000
# 5               NaN
# 6              4000
# 7              5000

# %% [markdown]
# Finally, we can extract the last number.

# %%
# extracts the second or last number 
df['max_annual_income'] = df['max_annual_income'].str.extract('(\d+)(?!.*\d)', expand=True)

# %%
df.ix[0:7,['max_annual_income']]
# Out:
#   max_annual_income
# 0              5000
# 1              5000
# 2              7000
# 3              5000
# 4             10000
# 5               NaN
# 6              4000
# 7              5000

# %% [markdown]
# __How can we create new attribute called `median income`? View the solution here.__

# %% [markdown]
# ## DataFrame to CSV

# %%
df.to_csv(r'clean_baltimore_data.csv')

# %%
clean_df = pd.read_csv("clean_baltimore_data.csv")
clean_df
# Out:
#     Unnamed: 0              Form     State Security_Grade  Area_Number  \
# 0            0  NS FORM-8 6-1-37  Maryland              A            2
# 1            1  NS FORM-8 6-1-37  Maryland              A            1
# 2            2  NS FORM-8 6-1-37  Maryland             A             3
# 3            3  NS FORM-8 6-1-37  Maryland              A            4
# 4            4  NS FORM-8 6-1-37  Maryland             A             5
# 5            5  NS FORM-8 6-1-37  Maryland              A            6
# 6            6  NS FORM-8 6-1-37  Maryland              B            1
# 7            7  NS FORM-8 6-1-37  Maryland              B            2
# 8            8  NS FORM-8 6-1-37  Maryland              B            3
# 9            9  NS FORM-8 6-1-37  Maryland              B            4
# 10          10  NS FORM-8 6-1-37  Maryland              B            5
# 11          11  NS FORM-8 6-1-37  Maryland              B            6
# 12          12  NS FORM-8 6-1-37  Maryland              B            7
# 13          13  NS FORM-8 6-1-37  Maryland              B            8
# 14          14  NS FORM-8 6-1-37  Maryland              B            9
# 15          15  NS FORM-8 6-1-37  Maryland              B           10
# 16          16  NS FORM-8 6-1-37  Maryland              B           11
# 17          17  NS FORM-8 6-1-37  Maryland              B           12
# 18          18  NS FORM-8 6-1-37  Maryland              B           14
# 19          19  NS FORM-8 6-1-37  Maryland              B           15
# 20          20  NS FORM-8 6-1-37  Maryland              B           16
# 21          21  NS FORM-8 6-1-37  Maryland              B           17
# 22          22  NS FORM-8 6-1-37  Maryland              B           18
# 23          23  NS FORM-8 6-1-37  Maryland              B           19
# 24          24  NS FORM-8 6-1-37  Maryland              B           20
# 25          25  NS FORM-8 6-1-37  Maryland              B           21
# 26          26  NS FORM-8 6-1-37  Maryland              B           22
# 27          27  NS FORM-8 6-1-37  Maryland              B           23
# 28          28  NS FORM-8 6-1-37  Maryland              C            7
# 29          29  NS FORM-8 6-1-37  Maryland              C            8
# 30          30  NS FORM-8 6-1-37  Maryland              C            9
# 31          31  NS FORM-8 6-1-37  Maryland              C           10
# 32          32  NS FORM-8 6-1-37  Maryland              C           11
# 33          33  NS FORM-8 6-1-37  Maryland              C           12
# 34          34  NS FORM-8 6-1-37  Maryland              C           13
# 35          35  NS FORM-8 6-1-37  Maryland              C           14
# 36          36  NS FORM-8 6-1-37  Maryland              C            1
# 37          37  NS FORM-8 6-1-37  Maryland              C            2
# 38          38  NS FORM-8 6-1-37  Maryland              C            3
# 39          39  NS FORM-8 6-1-37  Maryland              C            4
# 40          40  NS FORM-8 6-1-37  Maryland              C            5
# 41          41  NS FORM-8 6-1-37  Maryland              C            6
# 42          42  NS FORM-8 6-1-37  Maryland              C           15
# 43          43  NS FORM-8 6-1-37  Maryland              C           16
# 44          44  NS FORM-8 6-1-37  Maryland              C           17
# 45          45  NS FORM-8 6-1-37  Maryland              C           18
# 46          46  NS FORM-8 6-1-37  Maryland              C           19
# 47          47  NS FORM-8 6-1-37  Maryland              C           20
# 48          48  NS FORM-8 6-1-37  Maryland              C           21
# 49          49  NS FORM-8 6-1-37  Maryland              C           22
# 50          50  NS FORM-8 6-1-37  Maryland              D            1
# 51          51  NS FORM-8 6-1-37  Maryland              D            2
# 52          52  NS FORM-8 6-1-37  Maryland              D            4
# 53          53  NS FORM-8 6-1-37  Maryland              D            5
# 54          54  NS FORM-8 6-1-37  Maryland              D            6
# 55          55  NS FORM-8 6-1-37  Maryland              D            8
# 56          56  NS FORM-8 6-1-37  Maryland              D            9
#
#     Terrain_Description                               Favorable_Influences  \
# 0               Rolling  Fairly new suburban area of homogeneous charac...
# 1           Undulating   Very nicely planned residential area of medium...
# 2               Rolling               Good residential area. Well planned.
# 3                 Level                 Well planned development of fairly
# 4           Undulating   Desirable residential section. Good quality, m...
# 5               Rolling          To be developed as high grade development
# 6      Rolling to hilly  Desirable old residential section. Principally...
# 7      Rolling to hilly  Restricted, desirable residential section of m...
# 8            High level  Good residential section of fast moving property.
# 9      Rolling to level  Good suburban residential area of modest homes...
# 10          Undulating   Good residential section of homogeneous charac...
# 11              Rolling     Near Druid Hill Park. Close to center of city.
# 12           High level        Stable residential section of modest homes.
# 13              Rolling          Good residential area holding up in value
# 14          Undulating   Fairly good residential section with all conve...
# 15         Rolling high  Desirable residential section, homogeneous as ...
# 16              Rolling  Homogeneous development. Near to parks. Transp...
# 17                 Flat  Near to Sparrows Point. Desirable residential ...
# 18                Level    Quiet suburban section of homogeneous character
# 19                  NaN                   Outlying quiet suburban section.
# 20           High level  Stable old residential section of good character.
# 21                Level  Outlying quiet suburban section. County east o...
# 22              Rolling  Very high. Fairly new residential section of h...
# 23     Rolling to hilly  Desirable residential section of very good cha...
# 24                  NaN  Suburban atmosphere. Desirable residential sec...
# 25              Rolling  A fairly new development of single homes in de...
# 26                  NaN  The natural section for expansion from Liberty...
# 27                  NaN  Desirable residential section of good characte...
# 28              Rolling  Close to commercial area. Fairly desirable res...
# 29          High, level          Stable residential area of modest houses.
# 30                Level  Conversion value of location for business purp...
# 31              Rolling  Outlying residential section of small modest h...
# 32     Rolling to hilly                                               None
# 33              Rolling                    Proximity to industrial plants.
# 34              Rolling  Old residential section of modest character in...
# 35                  NaN    Fairly good residential section of modest homes
# 36  Level to undulating  Proximity to Patterson Park. Near to industria...
# 37                 Flat    Near to employment, particularly Sparrows Point
# 38         High rolling  Fairly desirable residential area of rather ol...
# 39          High, level  Close to commercial area. Goucher college loca...
# 40          High, level                      Proximity to Druid Hill Park.
# 41          High, level                           Close to commercial area
# 42                  NaN                                                NaN
# 43                  NaN                               Fairly good location
# 44                Level          Fairly desirable section of modest houses
# 45         High rolling                       On Washington-Baltimore Pike
# 46                  NaN                                Suburban atmosphere
# 47                  NaN   Similar in general character to Lansdowns (C-19)
# 48                  NaN  Similar in character to Lansdowne except furth...
# 49                  NaN           Similar in character to Lansdowne (C-19)
# 50  Level to undulating  Proximity to employment, industrial and commer...
# 51          Undulating                     Close to industrial employment.
# 52              Rolling             Good transportation. Central location.
# 53           Low, level                 Central location. Near employment.
# 54                Level                         Near desirable properties.
# 55              Rolling         Central locations. Conversion to business.
# 56  Level to undulating  Central location. Conversion value for busines...
#
#                                Detrimental_Influences  \
# 0                                                  No
# 1                                                  No
# 2                                    Distance to City
# 3                                                  No
# 4                                                  No
# 5                                                 NaN
# 6                                                  No
# 7                                                  No
# 8           Few streets of property in poor condition
# 9                                                  No
# 10                                                 No
# 11                            Built on filled ground.
# 12                                                 No
# 13                                                 No
# 14                         Distance to center of city
# 15                                                 No
# 16                                                 No
# 17      Distances to commercial area. Narrow streets.
# 18                                                 No
# 19           None except distances to center of city.
# 20                                                 No
# 21                                                 No
# 22                                                 No
# 23                         Distance to center of city
# 24                         Distance to center of city
# 25                         Distance to center of city
# 26                                                NaN
# 27                         Distance to center of city
# 28        Old style architecture. Heavy obsolescence
# 29                                                 No
# 30  Heavy traffic and disadvantage of commerce exc...
# 31      Bad location. Principally poor transportation
# 32                      Heavy traffic through section
# 33                                                NaN
# 34                     Heavy obsolescence of property
# 35                                                 No
# 36  Substantial age and disadvantages of industry ...
# 37  Distance to center of city. Smoke and noise fr...
# 38                             Old style architecture
# 39  Industrial plants. Continuing obsolescence of ...
# 40  Obsolescence and negro encroachment. Ground re...
# 41       Continuing obsolescence of old style houses.
# 42           A mediocre section of cheap construction
# 43                                 Cheap construction
# 44                         Distance to center of city
# 45                        Loss of RR from the section
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50  Heavy concentration of foreigners. Property is...
# 51  Mixture of foreign born. Disadvantage of indus...
# 52  Obsolescence. Negro concentration. Excessive G...
# 53       Heavy obsolescence. Industrial encroachment.
# 54  Houses in very bad condition. Many alley prope...
# 55  Interspersed with b business. Entire ward zone...
# 56  Heavy obsolescence of residential property. Bu...
#
#                            INHABITANTS_Type INHABITANTS_Annual_Income  \
# 0                  Substantial Middle Class             $3000 - 5,000
# 1              Executives, Professional Men                over $5000
# 2              Executives, Professional Men               3500 - 7000
# 3              Professional and Executives                 over $5000
# 4              Executives, Professional Men          $3,500 - $10,000
# 5                                       NaN                       NaN
# 6              Executives, Professional Men                over $4000
# 7              Executives, Professional Men                over $5000
# 8                              Business Men              $3000 and up
# 9                           Business people            $2500 to $4000
# 10                       White collar class            $2500 to $3500
# 11                       White collar class                   $3,000
# 12                                Mechanics            $2000 to $2500
# 13                             Middle class            $2500 to $3500
# 14                             Middle class            $2500 to $3500
# 15  Skilled mechanics and Junior Executives            $2000 to $4000
# 16                       White collar class            $2000 to $3000
# 17          Officers of Plants (industrial)                   $2,500
# 18                       White collar class              $3000 and up
# 19                             Business men            $3000 to $4000
# 20                          Business people            $3000 to $5000
# 21                             Business men           $2000 to $10000
# 22                       White collar class            $2000 to $3000
# 23                       White collar class              $3000 and up
# 24                       White collar class            $2000 to $4000
# 25                       White collar class                       NaN
# 26                                      NaN                       NaN
# 27                                      NaN                       NaN
# 28                        Clerks, mechanics            $1500 to $2500
# 29                     Business men, clerks            $1500 to $3000
# 30               White collar class, clerks                   $2,500
# 31                        Clerks, mechanics                   $2,000
# 32                  Mixture, laboring class                   $1,200
# 33                     Industrial employees                   $1,200
# 34                Skilled mechanics, clerks                   $1,800
# 35                       White collar class                   $2,500
# 36                            Skilled labor                   $1,500
# 37                       Industrial workers                   $1,200
# 38                Skilled mechanics, clerks                   $1,500
# 39                                  Mixture                   $2,000
# 40                          Mixture, Jewish                   $2,500
# 41                        Mechanics, clerks                   $1,500
# 42                        Mechanics, clerks            $1500 to $2500
# 43                                      NaN                       NaN
# 44                Clerks, skilled mechanics            $1500 to $2500
# 45                     Skilled labor clerks                       NaN
# 46                     Skilled labor clerks            $1000 to $2000
# 47                                      NaN                       NaN
# 48                                      NaN                       NaN
# 49                                      NaN                       NaN
# 50                                 Laborers                   $1,000
# 51                                  Mixture                   $1,000
# 52                                  Mixture                   $1,000
# 53                                 Laborers             $700 to $1000
# 54                                 Laborers             $700 to $1000
# 55                                  Mixture                       NaN
# 56                                  Mixture                       NaN
#
#           ...                             Ten_Fifteen_Desirability  \
# 0         ...                                               Upward
# 1         ...                                               Upward
# 2         ...                                               Upward
# 3         ...                                               Upward
# 4         ...                                               Upward
# 5         ...                                                  NaN
# 6         ...                                               Static
# 7         ...                                     Static to upward
# 8         ...                                     Static to upward
# 9         ...                                     Static to upward
# 10        ...                                               Static
# 11        ...                                     Static to upward
# 12        ...                                               Static
# 13        ...                                     Static to upward
# 14        ...                                               Static
# 15        ...                                     Static to upward
# 16        ...                                               Upward
# 17        ...                        Upward if steel mills operate
# 18        ...                                     Static to upward
# 19        ...                                     Static to upward
# 20        ...                                               Static
# 21        ...                                     Static to upward
# 22        ...                                     Static to upward
# 23        ...                            Static to possibly upward
# 24        ...                                                  NaN
# 25        ...                                                  NaN
# 26        ...                                                  NaN
# 27        ...                                                  NaN
# 28        ...                                             Downward
# 29        ...                                               Static
# 30        ...         Downward as residential, upward for commerce
# 31        ...                                             Downward
# 32        ...                                               Static
# 33        ...                                               Static
# 34        ...                                  Static to downward.
# 35        ...                                     Static to upward
# 36        ...                                  Static to downward.
# 37        ...                                  Static to downward.
# 38        ...                                               Static
# 39        ...                                               Static
# 40        ...                                               Static
# 41        ...                                             Downward
# 42        ...                                                  NaN
# 43        ...                                                  NaN
# 44        ...                                                  NaN
# 45        ...                                                  NaN
# 46        ...                                                  NaN
# 47        ...                                                  NaN
# 48        ...                                                  NaN
# 49        ...                                                  NaN
# 50        ...                                             Downward
# 51        ...                                             Downward
# 52        ...                                             Downward
# 53        ...                                             Downward
# 54        ...                                             Downward
# 55        ...                                             Downward
# 56        ...              Residential downward; commercial upward
#
#                                               Remarks        Date  City_clean  \
# 0   A recent development with much room for expans...  May 4,1937  Baltimore
# 1   Mostly fee properties. A few homes valued at $...  May 4,1937  Baltimore
# 2   Principally fee property. This section lies in...  May 4,1937  Baltimore
# 3                                    All fee property  May 4,1937  Baltimore
# 4   Merridale only recently developed. Prices do n...         NaN  Baltimore
# 5   Owned and controlled by the Roland Park Compan...         NaN  Baltimore
# 6   This section was completely built up in 1921. ...         NaN  Baltimore
# 7                          Principally fee property.   May 4,1937  Baltimore
# 8   Section is very spotty with poor houses lying ...  May 4,1937  Baltimore
# 9   Ground rent range $90 to $120. Part of the sec...  May 4,1937  Baltimore
# 10         Ground rents $90 to $120. Principally $90.  May 4,1937  Baltimore
# 11  Three story houses on Reisterstown Road are 25...  May 4,1937  Baltimore
# 12  Ground rents $60 to $90. Predominating $84. Fa...  May 4,1937  Baltimore
# 13  Ground rents $72 to $120. Ground rents in Ceda...  May 4,1937  Baltimore
# 14  This section lies in Baltimore County just out...  May 4,1937  Baltimore
# 15  Considered the best lending section in the cit...  May 4,1937  Baltimore
# 16  Ground rents range from $72 to $95. Predominat...  May 4,1937  Baltimore
# 17  Very few Ground Rents in Dundalk. This section...  May 4,1937  Baltimore
# 18    Principally fee property. Few ground rents $120  May 4,1937   Baltimore
# 19  Outside Baltimore City limits. A few larger ho...  May 4,1937  Baltimore
# 20  Many high-grade apartments are located along C...  May 4,1937   Baltimore
# 21                           Principally fee property  May 4,1937  Baltimore
# 22  Ground Rents range from $72 to $96. Predominat...  May 4,1937   Baltimore
# 23  Average held at $2000 to $2500 per acre. A spa...  May 4,1937  Baltimore
# 24  A sparsely settled section of modest homes. Pr...         NaN  Baltimore
# 25  This section has not taken the public's fancy ...         NaN  Baltimore
# 26  Still very sparsely settled, but may be expect...         NaN  Baltimore
# 27                                                NaN         NaN  Baltimore
# 28  Ground rents range from $50 to $50. Average $5...  May 4,1937   Baltimore
# 29  Ground rent range $60 to $90. This section has...  May 4,1937   Baltimore
# 30              Ground rents $72 to $120. Average $90  May 4,1937   Baltimore
# 31  Ground rent range $72 to $90.  Predominating. ...  May 4,1937   Baltimore
# 32  Ground rents range $43 to $72. Average $60. Ve...  May 4,1937   Baltimore
# 33         Ground rents $30 to $75. Predominating $60  May 4,1937   Baltimore
# 34  Ground rent range $42 to $90. Predominating $6...  May 4,1937   Baltimore
# 35    Ground rent range $72 to $95. Predominating $90  May 4,1937   Baltimore
# 36  This entire area is populated principally by p...  May 4,1937   Baltimore
# 37  Demand is expected to increase because of expa...  May 4,1937   Baltimore
# 38  Ground rents range from $48 to $75 and average...  May 4,1937   Baltimore
# 39  Ground rents range from $75 to $150 and averag...  May 4,1937   Baltimore
# 40  Houses are being converted into apartment unit...  May 4,1937   Baltimore
# 41  Ground rent $50 to $75 average $60. No immedia...  May 4,1937   Baltimore
# 42                      Very sparsely settled section         NaN  Baltimore
# 43  The section never seemed to go over very well ...         NaN  Baltimore
# 44  A rather presentable section of modest homes. ...         NaN  Baltimore
# 45  Some utilities are lacking . Principally fee p...         NaN  Baltimore
# 46  A sparsely settled section of fair character. ...         NaN  Baltimore
# 47                           Principally fee property  May 4,1937  Baltimore
# 48                           Principally fee property  May 4,1937  Baltimore
# 49                                                NaN         NaN  Baltimore
# 50  Ground rents in this section range from $36 to...  May 4,1937   Baltimore
# 51  Area become worse south of Eastern Avenue. Gro...  May 4,1937   Baltimore
# 52  Ground rents range from $42 to $120. Predomina...  May 4,1937   Baltimore
# 53  Ground rents in this section range from $30 to...  May 4,1937   Baltimore
# 54  Ground rents range $30 to $60. Predominating $...  May 4,1937   Baltimore
# 55  Valuations down do not include homes on Monume...  May 4,1937   Baltimore
# 56  Most of this section comprises the commercial ...  May 4,1937   Baltimore
#
#                          Suburb max_building_age    Year  Day Month  \
# 0                           NaN             10.0  1937.0  4.0   May
# 1                           NaN             12.0  1937.0  4.0   May
# 2                           NaN             20.0  1937.0  4.0   May
# 3                           NaN             10.0  1937.0  4.0   May
# 4                           NaN             20.0     NaN  NaN   NaN
# 5                     Northwood              NaN     NaN  NaN   NaN
# 6                           NaN             25.0     NaN  NaN   NaN
# 7                           NaN             25.0  1937.0  4.0   May
# 8                           NaN             15.0  1937.0  4.0   May
# 9                           NaN             25.0  1937.0  4.0   May
# 10                          NaN             20.0  1937.0  4.0   May
# 11                          NaN             10.0  1937.0  4.0   May
# 12                          NaN             10.0  1937.0  4.0   May
# 13                          NaN             25.0  1937.0  4.0   May
# 14            Metropolitan Area             20.0  1937.0  4.0   May
# 15                          NaN             25.0  1937.0  4.0   May
# 16                          NaN             12.0  1937.0  4.0   May
# 17                      Dundalk             20.0  1937.0  4.0   May
# 18                          NaN             20.0  1937.0  4.0   May
# 19                 Metropolitan             25.0  1937.0  4.0   May
# 20                          NaN             35.0  1937.0  4.0   May
# 21                 Metropolitan             25.0  1937.0  4.0   May
# 22                          NaN             15.0  1937.0  4.0   May
# 23                  Sub. Burton             25.0  1937.0  4.0   May
# 24   Sub. Mt. Washington Summit             40.0     NaN  NaN   NaN
# 25               Sub. Villahove              NaN     NaN  NaN   NaN
# 26           Sub. Colonial Park              NaN     NaN  NaN   NaN
# 27       Sub. Linthicum Heights              NaN     NaN  NaN   NaN
# 28                          NaN             50.0  1937.0  4.0   May
# 29                          NaN             20.0  1937.0  4.0   May
# 30                          NaN             35.0  1937.0  4.0   May
# 31                          NaN             15.0  1937.0  4.0   May
# 32                          NaN             20.0  1937.0  4.0   May
# 33                          NaN             25.0  1937.0  4.0   May
# 34                          NaN             60.0  1937.0  4.0   May
# 35                          NaN             15.0  1937.0  4.0   May
# 36                          NaN             45.0  1937.0  4.0   May
# 37                          NaN             15.0  1937.0  4.0   May
# 38                          NaN             40.0  1937.0  4.0   May
# 39                          NaN             35.0  1937.0  4.0   May
# 40                          NaN             50.0  1937.0  4.0   May
# 41                          NaN             50.0  1937.0  4.0   May
# 42                         Sub.              NaN     NaN  NaN   NaN
# 43     Sub. Catonsville Heights              NaN     NaN  NaN   NaN
# 44         Sub. Arbutus Terrace             30.0     NaN  NaN   NaN
# 45              Sub. Holethorpe              NaN     NaN  NaN   NaN
# 46               Sub. Lansdowne              NaN     NaN  NaN   NaN
# 47     Sub. Baltimore Highlands              NaN  1937.0  4.0   May
# 48         Sub. North Linthicum              NaN  1937.0  4.0   May
# 49                        Sub.               NaN     NaN  NaN   NaN
# 50                          NaN             65.0  1937.0  4.0   May
# 51                          NaN             60.0  1937.0  4.0   May
# 52                          NaN             50.0  1937.0  4.0   May
# 53                          NaN             60.0  1937.0  4.0   May
# 54                          NaN             35.0  1937.0  4.0   May
# 55                          NaN             60.0  1937.0  4.0   May
# 56                          NaN             60.0  1937.0  4.0   May
#
#    max_annual_income
# 0             5000.0
# 1             5000.0
# 2             7000.0
# 3             5000.0
# 4            10000.0
# 5                NaN
# 6             4000.0
# 7             5000.0
# 8             3000.0
# 9             4000.0
# 10            3500.0
# 11            3000.0
# 12            2500.0
# 13            3500.0
# 14            3500.0
# 15            4000.0
# 16            3000.0
# 17            2500.0
# 18            3000.0
# 19            4000.0
# 20            5000.0
# 21           10000.0
# 22            3000.0
# 23            3000.0
# 24            4000.0
# 25               NaN
# 26               NaN
# 27               NaN
# 28            2500.0
# 29            3000.0
# 30            2500.0
# 31            2000.0
# 32            1200.0
# 33            1200.0
# 34            1800.0
# 35            2500.0
# 36            1500.0
# 37            1200.0
# 38            1500.0
# 39            2000.0
# 40            2500.0
# 41            1500.0
# 42            2500.0
# 43               NaN
# 44            2500.0
# 45               NaN
# 46            2000.0
# 47               NaN
# 48               NaN
# 49               NaN
# 50            1000.0
# 51            1000.0
# 52            1000.0
# 53            1000.0
# 54            1000.0
# 55               NaN
# 56               NaN
#
# [57 rows x 33 columns]

# %% [markdown]
# Continue to the data maipulation portion of this module [here](Data Manipulation.ipynb)
