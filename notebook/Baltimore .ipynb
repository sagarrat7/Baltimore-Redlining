# %% [markdown]
# <img src="dcic.png">

# %% [markdown]
# # Mapping Inequality in Baltimore
# Contributors : Sarah Agarrat and Richard Marciano

# %% [markdown]
# ## Introduction
#
# After the 1929 Stock Market Crash, thousands of Americans were in danger of home foreclosure. To address this problem and stabilize the market, The Home Owners Loan Coperation (HOLC) was created under the Rooselvelt Administration to asses credibility of families in order to decide to refinance their homes.
#
# The HOLC created area descriptions and maps to "grade" neighborhoods based on racial/ethnic presence, the income of the residents, and environmental factors to determine their "financial risk". A grade of an 'D' (red) , was given to an area characterized as undesirable due to detrimental influences and unfavorable infiltration. Grade 'C' (yellow) areas were characterized by infiltration of a "lower grade population", "lacking homogeniety", and age of the neighborhoods, grade 'B' (blue) areas were completely developed, and 'grade 'A' (green) areas were characterized as "hot spots" that weren't fully built up yet and contained homogeinety. This is called __*redlining*__, denying financial services based on race/ethnic background.
#
#  <img src="baltimoremap-min.png" alt="Baltimore security grade map" title="Baltimore Security Grade Map" width=600>
#
# Learn more the Mapping Inequality Project [here.](https://dsl.richmond.edu/panorama/redlining/#loc=4/36.71/-96.93&opacity=0.8)

# %% [markdown]
# This notebook demonstrates computational techniques using attributes from the HOLC Baltimore records.  The topics covered are:
# - Aquiring Data
# - Data Cleaning and Data Preperation
# - Data Manipulation
# - Exploratory Data Analysis and Visualization

# %% [markdown]
# ## Aquiring Data

# %% [markdown]
# The fields of each record are characteristics of a graded section indicated by the security grade map seen above. These fields have been transcribed and stored in a __comma separated value (csv)__ format.
#
# Using the pandas library, we can create a data frame from the csv. A __data frame__ is a table where every row represents a single unique object, called an __entity__, and every column represents characteristics of these objects, called __attributes__.

# %% [markdown]
# ### Importing the Data and Creating a Data Frame

# %%
# loads the pandas library 
import pandas as pd

# creates data frame named df by reading in the Baltimore csv
df = pd.read_csv("AD_Data_BaltimoreProject.csv")
df
# Out:
#                 Form     State                                    City  \
# 0   NS FORM-8 6-1-37  Maryland                              Baltimore
# 1   NS FORM-8 6-1-37  Maryland                              Baltimore
# 2   NS FORM-8 6-1-37  Maryland                              Baltimore
# 3   NS FORM-8 6-1-37  Maryland                              Baltimore
# 4   NS FORM-8 6-1-37  Maryland                              Baltimore
# 5   NS FORM-8 6-1-37  Maryland                   Baltimore - Northwood
# 6   NS FORM-8 6-1-37  Maryland                              Baltimore
# 7   NS FORM-8 6-1-37  Maryland                              Baltimore
# 8   NS FORM-8 6-1-37  Maryland                              Baltimore
# 9   NS FORM-8 6-1-37  Maryland                              Baltimore
# 10  NS FORM-8 6-1-37  Maryland                              Baltimore
# 11  NS FORM-8 6-1-37  Maryland                              Baltimore
# 12  NS FORM-8 6-1-37  Maryland                              Baltimore
# 13  NS FORM-8 6-1-37  Maryland                              Baltimore
# 14  NS FORM-8 6-1-37  Maryland           Baltimore - Metropolitan Area
# 15  NS FORM-8 6-1-37  Maryland                              Baltimore
# 16  NS FORM-8 6-1-37  Maryland                              Baltimore
# 17  NS FORM-8 6-1-37  Maryland                     Baltimore - Dundalk
# 18  NS FORM-8 6-1-37  Maryland                               Baltimore
# 19  NS FORM-8 6-1-37  Maryland                Baltimore - Metropolitan
# 20  NS FORM-8 6-1-37  Maryland                               Baltimore
# 21  NS FORM-8 6-1-37  Maryland                Baltimore - Metropolitan
# 22  NS FORM-8 6-1-37  Maryland                               Baltimore
# 23  NS FORM-8 6-1-37  Maryland                 Baltimore - Sub. Burton
# 24  NS FORM-8 6-1-37  Maryland  Baltimore - Sub. Mt. Washington Summit
# 25  NS FORM-8 6-1-37  Maryland              Baltimore - Sub. Villahove
# 26  NS FORM-8 6-1-37  Maryland          Baltimore - Sub. Colonial Park
# 27  NS FORM-8 6-1-37  Maryland      Baltimore - Sub. Linthicum Heights
# 28  NS FORM-8 6-1-37  Maryland                               Baltimore
# 29  NS FORM-8 6-1-37  Maryland                               Baltimore
# 30  NS FORM-8 6-1-37  Maryland                               Baltimore
# 31  NS FORM-8 6-1-37  Maryland                               Baltimore
# 32  NS FORM-8 6-1-37  Maryland                               Baltimore
# 33  NS FORM-8 6-1-37  Maryland                               Baltimore
# 34  NS FORM-8 6-1-37  Maryland                               Baltimore
# 35  NS FORM-8 6-1-37  Maryland                               Baltimore
# 36  NS FORM-8 6-1-37  Maryland                               Baltimore
# 37  NS FORM-8 6-1-37  Maryland                               Baltimore
# 38  NS FORM-8 6-1-37  Maryland                               Baltimore
# 39  NS FORM-8 6-1-37  Maryland                               Baltimore
# 40  NS FORM-8 6-1-37  Maryland                               Baltimore
# 41  NS FORM-8 6-1-37  Maryland                               Baltimore
# 42  NS FORM-8 6-1-37  Maryland                        Baltimore - Sub.
# 43  NS FORM-8 6-1-37  Maryland    Baltimore - Sub. Catonsville Heights
# 44  NS FORM-8 6-1-37  Maryland        Baltimore - Sub. Arbutus Terrace
# 45  NS FORM-8 6-1-37  Maryland             Baltimore - Sub. Holethorpe
# 46  NS FORM-8 6-1-37  Maryland              Baltimore - Sub. Lansdowne
# 47  NS FORM-8 6-1-37  Maryland    Baltimore - Sub. Baltimore Highlands
# 48  NS FORM-8 6-1-37  Maryland        Baltimore - Sub. North Linthicum
# 49  NS FORM-8 6-1-37  Maryland                       Baltimore - Sub.
# 50  NS FORM-8 6-1-37  Maryland                               Baltimore
# 51  NS FORM-8 6-1-37  Maryland                               Baltimore
# 52  NS FORM-8 6-1-37  Maryland                               Baltimore
# 53  NS FORM-8 6-1-37  Maryland                               Baltimore
# 54  NS FORM-8 6-1-37  Maryland                               Baltimore
# 55  NS FORM-8 6-1-37  Maryland                               Baltimore
# 56  NS FORM-8 6-1-37  Maryland                               Baltimore
#
#    Security_Grade  Area_Number  Terrain_Description  \
# 0               A            2              Rolling
# 1               A            1          Undulating
# 2              A             3              Rolling
# 3               A            4                Level
# 4              A             5          Undulating
# 5               A            6              Rolling
# 6               B            1     Rolling to hilly
# 7               B            2     Rolling to hilly
# 8               B            3           High level
# 9               B            4     Rolling to level
# 10              B            5          Undulating
# 11              B            6              Rolling
# 12              B            7           High level
# 13              B            8              Rolling
# 14              B            9          Undulating
# 15              B           10         Rolling high
# 16              B           11              Rolling
# 17              B           12                 Flat
# 18              B           14                Level
# 19              B           15                  NaN
# 20              B           16           High level
# 21              B           17                Level
# 22              B           18              Rolling
# 23              B           19     Rolling to hilly
# 24              B           20                  NaN
# 25              B           21              Rolling
# 26              B           22                  NaN
# 27              B           23                  NaN
# 28              C            7              Rolling
# 29              C            8          High, level
# 30              C            9                Level
# 31              C           10              Rolling
# 32              C           11     Rolling to hilly
# 33              C           12              Rolling
# 34              C           13              Rolling
# 35              C           14                  NaN
# 36              C            1  Level to undulating
# 37              C            2                 Flat
# 38              C            3         High rolling
# 39              C            4          High, level
# 40              C            5          High, level
# 41              C            6          High, level
# 42              C           15                  NaN
# 43              C           16                  NaN
# 44              C           17                Level
# 45              C           18         High rolling
# 46              C           19                  NaN
# 47              C           20                  NaN
# 48              C           21                  NaN
# 49              C           22                  NaN
# 50              D            1  Level to undulating
# 51              D            2          Undulating
# 52              D            4              Rolling
# 53              D            5           Low, level
# 54              D            6                Level
# 55              D            8              Rolling
# 56              D            9  Level to undulating
#
#                                  Favorable_Influences  \
# 0   Fairly new suburban area of homogeneous charac...
# 1   Very nicely planned residential area of medium...
# 2                Good residential area. Well planned.
# 3                  Well planned development of fairly
# 4   Desirable residential section. Good quality, m...
# 5           To be developed as high grade development
# 6   Desirable old residential section. Principally...
# 7   Restricted, desirable residential section of m...
# 8   Good residential section of fast moving property.
# 9   Good suburban residential area of modest homes...
# 10  Good residential section of homogeneous charac...
# 11     Near Druid Hill Park. Close to center of city.
# 12        Stable residential section of modest homes.
# 13          Good residential area holding up in value
# 14  Fairly good residential section with all conve...
# 15  Desirable residential section, homogeneous as ...
# 16  Homogeneous development. Near to parks. Transp...
# 17  Near to Sparrows Point. Desirable residential ...
# 18    Quiet suburban section of homogeneous character
# 19                   Outlying quiet suburban section.
# 20  Stable old residential section of good character.
# 21  Outlying quiet suburban section. County east o...
# 22  Very high. Fairly new residential section of h...
# 23  Desirable residential section of very good cha...
# 24  Suburban atmosphere. Desirable residential sec...
# 25  A fairly new development of single homes in de...
# 26  The natural section for expansion from Liberty...
# 27  Desirable residential section of good characte...
# 28  Close to commercial area. Fairly desirable res...
# 29          Stable residential area of modest houses.
# 30  Conversion value of location for business purp...
# 31  Outlying residential section of small modest h...
# 32                                               None
# 33                    Proximity to industrial plants.
# 34  Old residential section of modest character in...
# 35    Fairly good residential section of modest homes
# 36  Proximity to Patterson Park. Near to industria...
# 37    Near to employment, particularly Sparrows Point
# 38  Fairly desirable residential area of rather ol...
# 39  Close to commercial area. Goucher college loca...
# 40                      Proximity to Druid Hill Park.
# 41                           Close to commercial area
# 42                                                NaN
# 43                               Fairly good location
# 44          Fairly desirable section of modest houses
# 45                       On Washington-Baltimore Pike
# 46                                Suburban atmosphere
# 47   Similar in general character to Lansdowns (C-19)
# 48  Similar in character to Lansdowne except furth...
# 49           Similar in character to Lansdowne (C-19)
# 50  Proximity to employment, industrial and commer...
# 51                    Close to industrial employment.
# 52             Good transportation. Central location.
# 53                 Central location. Near employment.
# 54                         Near desirable properties.
# 55         Central locations. Conversion to business.
# 56  Central location. Conversion value for busines...
#
#                                Detrimental_Influences  \
# 0                                                None
# 1                                                None
# 2                                    Distance to City
# 3                                                None
# 4                                                None
# 5                                                 NaN
# 6                                                 No.
# 7                                                None
# 8           Few streets of property in poor condition
# 9                                                None
# 10                                               None
# 11                            Built on filled ground.
# 12                                               None
# 13                                               None
# 14                         Distance to center of city
# 15                                               None
# 16                                               None
# 17      Distances to commercial area. Narrow streets.
# 18                                                 No
# 19           None except distances to center of city.
# 20                                               None
# 21                                                 No
# 22                                               None
# 23                         Distance to center of city
# 24                         Distance to center of city
# 25                         Distance to center of city
# 26                                                NaN
# 27                         Distance to center of city
# 28        Old style architecture. Heavy obsolescence
# 29                                               None
# 30  Heavy traffic and disadvantage of commerce exc...
# 31      Bad location. Principally poor transportation
# 32                      Heavy traffic through section
# 33                                                NaN
# 34                     Heavy obsolescence of property
# 35                                                 No
# 36  Substantial age and disadvantages of industry ...
# 37  Distance to center of city. Smoke and noise fr...
# 38                             Old style architecture
# 39  Industrial plants. Continuing obsolescence of ...
# 40  Obsolescence and negro encroachment. Ground re...
# 41       Continuing obsolescence of old style houses.
# 42           A mediocre section of cheap construction
# 43                                 Cheap construction
# 44                         Distance to center of city
# 45                        Loss of RR from the section
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50  Heavy concentration of foreigners. Property is...
# 51  Mixture of foreign born. Disadvantage of indus...
# 52  Obsolescence. Negro concentration. Excessive G...
# 53       Heavy obsolescence. Industrial encroachment.
# 54  Houses in very bad condition. Many alley prope...
# 55  Interspersed with b business. Entire ward zone...
# 56  Heavy obsolescence of residential property. Bu...
#
#                            INHABITANTS_Type INHABITANTS_Annual_Income  \
# 0                  Substantial Middle Class             $3000 - 5,000
# 1              Executives, Professional Men                over $5000
# 2              Executives, Professional Men               3500 - 7000
# 3              Professional and Executives                 over $5000
# 4              Executives, Professional Men          $3,500 - $10,000
# 5                                       NaN                       NaN
# 6              Executives, Professional Men                over $4000
# 7              Executives, Professional Men                over $5000
# 8                              Business Men              $3000 and up
# 9                           Business people            $2500 to $4000
# 10                       White collar class            $2500 to $3500
# 11                       White collar class                   $3,000
# 12                                Mechanics            $2000 to $2500
# 13                             Middle class            $2500 to $3500
# 14                             Middle class            $2500 to $3500
# 15  Skilled mechanics and Junior Executives            $2000 to $4000
# 16                       White collar class            $2000 to $3000
# 17          Officers of Plants (industrial)                   $2,500
# 18                       White collar class              $3000 and up
# 19                             Business men            $3000 to $4000
# 20                          Business people            $3000 to $5000
# 21                             Business men           $2000 to $10000
# 22                       White collar class            $2000 to $3000
# 23                       White collar class              $3000 and up
# 24                       White collar class            $2000 to $4000
# 25                       White collar class                       NaN
# 26                                      NaN                       NaN
# 27                                      NaN                       NaN
# 28                        Clerks, mechanics            $1500 to $2500
# 29                     Business men, clerks            $1500 to $3000
# 30               White collar class, clerks                   $2,500
# 31                        Clerks, mechanics                   $2,000
# 32                  Mixture, laboring class                   $1,200
# 33                     Industrial employees                   $1,200
# 34                Skilled mechanics, clerks                   $1,800
# 35                       White collar class                   $2,500
# 36                            Skilled labor                   $1,500
# 37                       Industrial workers                   $1,200
# 38                Skilled mechanics, clerks                   $1,500
# 39                                  Mixture                   $2,000
# 40                          Mixture, Jewish                   $2,500
# 41                        Mechanics, clerks                   $1,500
# 42                        Mechanics, clerks            $1500 to $2500
# 43                                      NaN                       NaN
# 44                Clerks, skilled mechanics            $1500 to $2500
# 45                     Skilled labor clerks                       NaN
# 46                     Skilled labor clerks            $1000 to $2000
# 47                                      NaN                       NaN
# 48                                      NaN                       NaN
# 49                                      NaN                       NaN
# 50                                 Laborers                   $1,000
# 51                                  Mixture                   $1,000
# 52                                  Mixture                   $1,000
# 53                                 Laborers             $700 to $1000
# 54                                 Laborers             $700 to $1000
# 55                                  Mixture                       NaN
# 56                                  Mixture                       NaN
#
#        ...     INHABITANTS_Population_Increase  \
# 0      ...                               Fast
# 1      ...                     Moderately Fast
# 2      ...                     Moderately Fast
# 3      ...                              Slowly
# 4      ...                     Moderately Fast
# 5      ...                                 NaN
# 6      ...                                 NaN
# 7      ...                              Slowly
# 8      ...                     Moderately Fast
# 9      ...                     Moderately Fast
# 10     ...                                 NaN
# 11     ...                              Slowly
# 12     ...                              Slowly
# 13     ...                          Moderately
# 14     ...                              Slowly
# 15     ...                               Fast
# 16     ...                     Moderately fast
# 17     ...                          Moderately
# 18     ...                              Slowly
# 19     ...                              Slowly
# 20     ...                                 NaN
# 21     ...                              Slowly
# 22     ...                               Fast
# 23     ...                              Slowly
# 24     ...                                 NaN
# 25     ...                                 NaN
# 26     ...                                 NaN
# 27     ...                                 NaN
# 28     ...                                 NaN
# 29     ...                              Slowly
# 30     ...                                 NaN
# 31     ...                                 NaN
# 32     ...                         Very slowly
# 33     ...                         Fairly fast
# 34     ...                                 NaN
# 35     ...                              Slowly
# 36     ...                                 NaN
# 37     ...                              Slowly
# 38     ...                                 NaN
# 39     ...                                 NaN
# 40     ...                                 NaN
# 41     ...                                 NaN
# 42     ...                                 NaN
# 43     ...                                 NaN
# 44     ...                                 NaN
# 45     ...                                 NaN
# 46     ...                                 NaN
# 47     ...                                 NaN
# 48     ...                                 NaN
# 49     ...                                 NaN
# 50     ...                                 NaN
# 51     ...                                 NaN
# 52     ...                                 NaN
# 53     ...                                 NaN
# 54     ...                                 NaN
# 55     ...                                 NaN
# 56     ...                                 NaN
#
#     INHABITANTS_Population_Decrease INHABITANTS_Population_Static  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# 5                               NaN                           NaN
# 6                               NaN                           Yes
# 7                               NaN                           NaN
# 8                               NaN                           NaN
# 9                               NaN                           NaN
# 10                              NaN                           Yes
# 11                              NaN                           NaN
# 12                              NaN                           NaN
# 13                              NaN                           NaN
# 14                              NaN                           NaN
# 15                              NaN                           NaN
# 16                              NaN                           NaN
# 17                              NaN                           NaN
# 18                              NaN                           NaN
# 19                              NaN                           NaN
# 20                              NaN                           Yes
# 21                              NaN                           NaN
# 22                              NaN                           NaN
# 23                              NaN                           NaN
# 24                              NaN                           Yes
# 25                              NaN                           NaN
# 26                              NaN                           NaN
# 27                              NaN                           NaN
# 28                              NaN                           Yes
# 29                              NaN                           NaN
# 30                              NaN                           Yes
# 31                              NaN                           Yes
# 32                              NaN                           NaN
# 33                              NaN                           NaN
# 34                              NaN                           Yes
# 35                              NaN                           NaN
# 36                           Slowly                           NaN
# 37                              NaN                           NaN
# 38                              NaN                           Yes
# 39                              NaN                           Yes
# 40                              NaN                           Yes
# 41                              NaN                           Yes
# 42                              NaN                           NaN
# 43                              NaN                           NaN
# 44                              NaN                           NaN
# 45                              NaN                           NaN
# 46                              NaN                           NaN
# 47                              NaN                           NaN
# 48                              NaN                           NaN
# 49                              NaN                           NaN
# 50                             Fast                           NaN
# 51                             Fast                           NaN
# 52                             Fast                           NaN
# 53                           Slowly                           Yes
# 54                              NaN                           yes
# 55                             Fast                           NaN
# 56                             Fast                           NaN
#
#                              BUILDINGS_Types    BUILDINGS_Construction  \
# 0                     Detached an row houses           Brick and frame
# 1                     Single family detached           Brick and Stone
# 2                        One family detached   Brick, Stone, and Frame
# 3                                One  family   Brick, Stone, and Frame
# 4                        One family detached           Brick and Stone
# 5                                    Single                    Masonry
# 6                        One family detached                     Frame
# 7                        One family detached           Frame and Brick
# 8                            Single detached           Brick and Frame
# 9                         One family cottage                     Frame
# 10                             Two story row                     Brick
# 11                             Two story row                     Brick
# 12           Two story row and semi detached                     Brick
# 13                        One family cottage                     Frame
# 14                       One family detached           Brick and frame
# 15                       One family detached           Frame and Brick
# 16                             Two story row                     Brick
# 17                                 Detached   Brick, Stucco, and Frame
# 18                        One family cottage                     Frame
# 19                          Detached singles           Brick and frame
# 20                   Two and three story row                     Brick
# 21                       One family detached                     Frame
# 22                            Two story rows                     Brick
# 23                                   Singles             Frame masonry
# 24                                   Singles                     Frame
# 25                                       NaN                       NaN
# 26                                       NaN                       NaN
# 27                                   Singles                     Frame
# 28                             Two story row                     Brick
# 29      Two story row houses & semi detached                     Brick
# 30  Cottages on east side, Rows on west side           Frame and Brick
# 31                       One family detached                     Frame
# 32                                 Bungalows                     Frame
# 33                                Row houses           Brick and frame
# 34                   Two and three story row                     Brick
# 35               Two story cottages and rows           Frame and Brick
# 36                   Two and three story row                     Brick
# 37                       One family cottages                     Frame
# 38                   Two and three story row                     Brick
# 39                           Three story row                     Brick
# 40                           Three story row                     Brick
# 41                             Two story row                     Brick
# 42                                       NaN                       NaN
# 43                                       NaN                       NaN
# 44                     Bungalows to cottages                     Frame
# 45                                       NaN                       NaN
# 46                                   Singles                     Frame
# 47                                   Singles                     Frame
# 48                                   Singles                     Frame
# 49                                       NaN                       NaN
# 50                           Three story row                     Brick
# 51                    Two to three story row                     Brick
# 52                   Two and three story row                     Brick
# 53                   Two and three story row                     Brick
# 54                            Two story rows                     Brick
# 55                           Three story row                     Brick
# 56                   Two and three story row                     Brick
#
#              BUILDINGS_Age   BUILDINGS_Repair  \
# 0            1 to 10 years               Good
# 1                 12 years          Very good
# 2            1 to 20 years  Good to excellent
# 3                 10 years               Good
# 4            1 to 20 years               Good
# 5                      NaN                NaN
# 6                 25 years               Good
# 7           15 to 25 years               Good
# 8                 15 years               Good
# 9            5 to 25 years               Good
# 10                20 years        Fairly Good
# 11           5 to 10 years               Good
# 12                10 years               Good
# 13                25 years               Good
# 14           1 to 20 years        Fairly Good
# 15           6 to 25 years               Good
# 16                12 years          Very good
# 17                20 years        Fairly Good
# 18                20 years               Good
# 19           1 to 25 years               Good
# 20                35 years               Good
# 21                25 years               Good
# 22           1 to 15 years               Good
# 23          15 to 25 years               Good
# 24          20 to 40 years        Fairly Good
# 25                     NaN                NaN
# 26                     NaN                NaN
# 27                     NaN                NaN
# 28          35 to 50 years               Fair
# 29                20 years        Fairly Good
# 30  Row 20, Frame 35 years       Fair to good
# 31                15 years               Fair
# 32                20 Years               Fair
# 33                25 years               Fair
# 34          40 to 60 years               Fair
# 35                15 years               Good
# 36          25 to 45 years               Fair
# 37                15 years               Fair
# 38                40 years               Fair
# 39                35 years        Fairly Good
# 40          40 to 50 years               Fair
# 41          35 to 50 years       Fair to good
# 42                     NaN                NaN
# 43                     NaN                NaN
# 44           1 to 30 years        Fairly Good
# 45                     NaN                NaN
# 46                     NaN                NaN
# 47                     NaN                NaN
# 48                     NaN                NaN
# 49                     NaN                NaN
# 50                65 years               Poor
# 51                      60      Poor to fair
# 52                50 years               Poor
# 53                60 years               Poor
# 54                35 years               Poor
# 55                60 years               Poor
# 56                60 years      Poor to fair
#
#                         Ten_Fifteen_Desirability  \
# 0                                         Upward
# 1                                         Upward
# 2                                         Upward
# 3                                         Upward
# 4                                         Upward
# 5                                            NaN
# 6                                         Static
# 7                               Static to upward
# 8                               Static to upward
# 9                               Static to upward
# 10                                        Static
# 11                              Static to upward
# 12                                        Static
# 13                              Static to upward
# 14                                        Static
# 15                              Static to upward
# 16                                        Upward
# 17                 Upward if steel mills operate
# 18                              Static to upward
# 19                              Static to upward
# 20                                        Static
# 21                              Static to upward
# 22                              Static to upward
# 23                     Static to possibly upward
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                      Downward
# 29                                        Static
# 30  Downward as residential, upward for commerce
# 31                                      Downward
# 32                                        Static
# 33                                        Static
# 34                           Static to downward.
# 35                              Static to upward
# 36                           Static to downward.
# 37                           Static to downward.
# 38                                        Static
# 39                                        Static
# 40                                        Static
# 41                                      Downward
# 42                                           NaN
# 43                                           NaN
# 44                                           NaN
# 45                                           NaN
# 46                                           NaN
# 47                                           NaN
# 48                                           NaN
# 49                                           NaN
# 50                                      Downward
# 51                                      Downward
# 52                                      Downward
# 53                                      Downward
# 54                                      Downward
# 55                                      Downward
# 56       Residential downward; commercial upward
#
#                                               Remarks        Date
# 0   A recent development with much room for expans...  May 4,1937
# 1   Mostly fee properties. A few homes valued at $...  May 4,1937
# 2   Principally fee property. This section lies in...  May 4,1937
# 3                                    All fee property  May 4,1937
# 4   Merridale only recently developed. Prices do n...         NaN
# 5   Owned and controlled by the Roland Park Compan...         NaN
# 6   This section was completely built up in 1921. ...         NaN
# 7                          Principally fee property.   May 4,1937
# 8   Section is very spotty with poor houses lying ...  May 4,1937
# 9   Ground rent range $90 to $120. Part of the sec...  May 4,1937
# 10         Ground rents $90 to $120. Principally $90.  May 4,1937
# 11  Three story houses on Reisterstown Road are 25...  May 4,1937
# 12  Ground rents $60 to $90. Predominating $84. Fa...  May 4,1937
# 13  Ground rents $72 to $120. Ground rents in Ceda...  May 4,1937
# 14  This section lies in Baltimore County just out...  May 4,1937
# 15  Considered the best lending section in the cit...  May 4,1937
# 16  Ground rents range from $72 to $95. Predominat...  May 4,1937
# 17  Very few Ground Rents in Dundalk. This section...  May 4,1937
# 18    Principally fee property. Few ground rents $120  May 4,1937
# 19  Outside Baltimore City limits. A few larger ho...  May 4,1937
# 20  Many high-grade apartments are located along C...  May 4,1937
# 21                           Principally fee property  May 4,1937
# 22  Ground Rents range from $72 to $96. Predominat...  May 4,1937
# 23  Average held at $2000 to $2500 per acre. A spa...  May 4,1937
# 24  A sparsely settled section of modest homes. Pr...         NaN
# 25  This section has not taken the public's fancy ...         NaN
# 26  Still very sparsely settled, but may be expect...         NaN
# 27                                                NaN         NaN
# 28  Ground rents range from $50 to $50. Average $5...  May 4,1937
# 29  Ground rent range $60 to $90. This section has...  May 4,1937
# 30              Ground rents $72 to $120. Average $90  May 4,1937
# 31  Ground rent range $72 to $90.  Predominating. ...  May 4,1937
# 32  Ground rents range $43 to $72. Average $60. Ve...  May 4,1937
# 33         Ground rents $30 to $75. Predominating $60  May 4,1937
# 34  Ground rent range $42 to $90. Predominating $6...  May 4,1937
# 35    Ground rent range $72 to $95. Predominating $90  May 4,1937
# 36  This entire area is populated principally by p...  May 4,1937
# 37  Demand is expected to increase because of expa...  May 4,1937
# 38  Ground rents range from $48 to $75 and average...  May 4,1937
# 39  Ground rents range from $75 to $150 and averag...  May 4,1937
# 40  Houses are being converted into apartment unit...  May 4,1937
# 41  Ground rent $50 to $75 average $60. No immedia...  May 4,1937
# 42                      Very sparsely settled section         NaN
# 43  The section never seemed to go over very well ...         NaN
# 44  A rather presentable section of modest homes. ...         NaN
# 45  Some utilities are lacking . Principally fee p...         NaN
# 46  A sparsely settled section of fair character. ...         NaN
# 47                           Principally fee property  May 4,1937
# 48                           Principally fee property  May 4,1937
# 49                                                NaN         NaN
# 50  Ground rents in this section range from $36 to...  May 4,1937
# 51  Area become worse south of Eastern Avenue. Gro...  May 4,1937
# 52  Ground rents range from $42 to $120. Predomina...  May 4,1937
# 53  Ground rents in this section range from $30 to...  May 4,1937
# 54  Ground rents range $30 to $60. Predominating $...  May 4,1937
# 55  Valuations down do not include homes on Monume...  May 4,1937
# 56  Most of this section comprises the commercial ...  May 4,1937
#
# [57 rows x 26 columns]

# %% [markdown]
# <img src="Baltimore_AD_002.png" width=400 >
#
# In this form, `SECUIRITY GRADE` has value A and `AREA NO.` has value 2. This form is located in the first row with index 0 in the data frame.

# %% [markdown]
# ## Data Cleaning and Preparation

# %% [markdown]
# After obtaining our data, we need to clean it to prepare for data analysis. This includes handling similiar text values and making sure a column of interest contains a single attribute.

# %% [markdown]
# ### Handling Text Values with Similar Meanings

# %% [markdown]
# The `INHABITANTS_Foreignborn` varaible indicates whether there are foreigners in a neighborhood section. Observe that different forms used 'No' or 'None' to indicate there are no foreigners and 'Small' , 'Very few' , and 'Mixture' are various ways of indicating there were foreigners. `NaN` indicates the value in the form is missing.

# %%
# selects rows with indices between 0 to 15 included of the 'INHABITANTS_Foreignborn' column
df.ix[0:15,'INHABITANTS_Foreignborn']
# Out:
# 0           No
# 1         None
# 2         None
# 3         None
# 4         None
# 5          NaN
# 6           No
# 7           No
# 8           No
# 9        Small
# 10    Very few
# 11          No
# 12          No
# 13          No
# 14          No
# 15     Mixture
# Name: INHABITANTS_Foreignborn, dtype: object

# %% [markdown]
# Since columns with categorized values are easier to analyze, we are going to transform this column to indicate whether there are foreigners or not. In Python, `None` is a special keyword that indicates the cell has a null value. Therefore, we will alter all the 'None' values to 'No' and every other value that indicates there are to 'Yes'.

# %%
# replaces the values of 'None' with 'No'
df['INHABITANTS_Foreignborn'] = df['INHABITANTS_Foreignborn'].replace('None', 'No')

# replaces all other values with 'Yes'
for value in df['INHABITANTS_Foreignborn']:
    if value != 'No' and value != 'NaN':
        df['INHABITANTS_Foreignborn'] = df['INHABITANTS_Foreignborn'].replace(value, 'Yes')

df.ix[0:15,'INHABITANTS_Foreignborn']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
# 5     Yes
# 6      No
# 7      No
# 8      No
# 9     Yes
# 10    Yes
# 11     No
# 12     No
# 13     No
# 14     No
# 15    Yes
# Name: INHABITANTS_Foreignborn, dtype: object

# %% [markdown]
# `Detrimental_Influences`  are descriptions of a region's undesiriable characteristics. Notice in this case that there are multiple variations of the meaning of 'No' to be replaced.

# %%
df.ix[0:15,'Detrimental_Influences']
# Out:
# 0                                          None
# 1                                          None
# 2                              Distance to City
# 3                                          None
# 4                                          None
# 5                                           NaN
# 6                                           No.
# 7                                          None
# 8     Few streets of property in poor condition
# 9                                          None
# 10                                         None
# 11                      Built on filled ground.
# 12                                         None
# 13                                         None
# 14                   Distance to center of city
# 15                                         None
# Name: Detrimental_Influences, dtype: object

# %% [markdown]
# To handle the multiple words to be replaced we can use an __array__, a list that holds a fixed number of values of the same type, to store several strings. Then we can replace each occurence in `Detrimental_Influences` by iterating through the array and using the `replace()` function.

# %%
# declares an array called 'no_words' containing strings that all mean 'No'
no_words = ['No.','no', 'none', 'None']

# interates through no_words and replaces each occurence in Detrimental_Influences
for word in no_words:
    df['Detrimental_Influences'] = df['Detrimental_Influences'].replace( word , 'No')

# %%
df.ix[0:15,'Detrimental_Influences']
# Out:
# 0                                            No
# 1                                            No
# 2                              Distance to City
# 3                                            No
# 4                                            No
# 5                                           NaN
# 6                                            No
# 7                                            No
# 8     Few streets of property in poor condition
# 9                                            No
# 10                                           No
# 11                      Built on filled ground.
# 12                                           No
# 13                                           No
# 14                   Distance to center of city
# 15                                           No
# Name: Detrimental_Influences, dtype: object

# %% [markdown]
# We need to do these same operations for `INHABITANTS_Negro`, whether residents are African American, and `INHABITANTS_Infiltration`, which refers to if the area is being infiltrated. __Functions__ are procedures that perform specific tasks. In Python, we can create our own functions or used built-in functions such as `replace()`. __Parameters__ are variables that are defined in the function definition. __Arguments__ are the values passed into a function.
#
# The `replace_values` function has three parmeters : `attribute`, `new_word`, and `words_to_replace`.

# %%
# this function iterates through an array of words to be replaced and replaces each occurence in the attribute 
# with the new word
def replace_values(attribute, new_word, words_to_replace):
    for word in words_to_replace:
        df[attribute] = df[attribute].replace(word, new_word) 


replace_values('INHABITANTS_Negro', 'No', no_words)
replace_values('INHABITANTS_Infiltration', 'No', no_words)

# %%
df.ix[0:15,'INHABITANTS_Infiltration']
# Out:
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# 5                 NaN
# 6                  No
# 7                  No
# 8                  No
# 9                 NaN
# 10                 No
# 11                 No
# 12                 No
# 13                 No
# 14                 No
# 15    People from C-1
# Name: INHABITANTS_Infiltration, dtype: object

# %% [markdown]
# Note that we do the same procedure for words meaning 'few', however we could have made these columns have two categories, 'yes' or 'no', and indicate in our data analysis the alterations to our data.

# %%
# Various words meaning small 
small_words = ['Nominal','nominal', 'Small','small','Minimum', 'minimum','minimal', 'Very few']

replace_values('INHABITANTS_Negro', 'Few', small_words)
replace_values('INHABITANTS_Infiltration', 'Few', small_words)

# %%
df.ix[0:15,'INHABITANTS_Infiltration']
# Out:
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# 5                 NaN
# 6                  No
# 7                  No
# 8                  No
# 9                 NaN
# 10                 No
# 11                 No
# 12                 No
# 13                 No
# 14                 No
# 15    People from C-1
# Name: INHABITANTS_Infiltration, dtype: object

# %%
df.ix[0:15,'INHABITANTS_Negro']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
# 5     NaN
# 6      No
# 7      No
# 8      No
# 9      No
# 10     No
# 11     No
# 12     No
# 13     No
# 14     No
# 15     No
# Name: INHABITANTS_Negro, dtype: object

# %% [markdown]
# We can clean up the values of `INHABITANTS_Population_Increase`, how the population is increasing in an area, by choosing standard categories for the rate the population.

# %%
 df.ix[0:15,'INHABITANTS_Population_Increase']
# Out:
# 0               Fast
# 1     Moderately Fast
# 2     Moderately Fast
# 3              Slowly
# 4     Moderately Fast
# 5                 NaN
# 6                 NaN
# 7              Slowly
# 8     Moderately Fast
# 9     Moderately Fast
# 10                NaN
# 11             Slowly
# 12             Slowly
# 13         Moderately
# 14             Slowly
# 15              Fast
# Name: INHABITANTS_Population_Increase, dtype: object

# %% [markdown]
# We will define rates of the population as very slowly, slowly, moderately, moderately fast, fast based on the data.

# %%
# defines values to replace in the table 
very_slowly = ['Very Slowly', 'very slowly', 'very Slowly']
slowly = ['slowly', 'fairly slowly']
moderately = ['moderately']
moderately_fast = ['Moderately Fast', 'moderately Fast', 'moderately fast']
fast = ['very fast', 'Very Fast', 'fast']

# applies function to obtain our new values 
replace_values('INHABITANTS_Population_Increase', 'Very slowly', very_slowly)
replace_values('INHABITANTS_Population_Increase', 'Slowly', slowly)
replace_values('INHABITANTS_Population_Increase', 'Moderately', moderately )
replace_values('INHABITANTS_Population_Increase', 'Moderately fast', moderately_fast)
replace_values('INHABITANTS_Population_Increase', 'Moderately fast', moderately_fast)
replace_values('INHABITANTS_Population_Increase', 'Fast', fast)

# %%
 df.ix[0:15,'INHABITANTS_Population_Increase']
# Out:
# 0               Fast
# 1     Moderately fast
# 2     Moderately fast
# 3              Slowly
# 4     Moderately fast
# 5                 NaN
# 6                 NaN
# 7              Slowly
# 8     Moderately fast
# 9     Moderately fast
# 10                NaN
# 11             Slowly
# 12             Slowly
# 13         Moderately
# 14             Slowly
# 15              Fast
# Name: INHABITANTS_Population_Increase, dtype: object

# %% [markdown]
# ### String Parsing to Extract Data

# %% [markdown]
# Some of the cities have corresponding suburbs followed by a dash. We can extract the suburbs and create a new column using  `str.split()`.

# %%
df.ix[16:30,'City']
# Out:
# 16                                Baltimore
# 17                       Baltimore - Dundalk
# 18                                 Baltimore
# 19                  Baltimore - Metropolitan
# 20                                 Baltimore
# 21                  Baltimore - Metropolitan
# 22                                 Baltimore
# 23                   Baltimore - Sub. Burton
# 24    Baltimore - Sub. Mt. Washington Summit
# 25                Baltimore - Sub. Villahove
# 26            Baltimore - Sub. Colonial Park
# 27        Baltimore - Sub. Linthicum Heights
# 28                                 Baltimore
# 29                                 Baltimore
# 30                                 Baltimore
# Name: City, dtype: object

# %% [markdown]
#  A new data frame seperate is created with two columns seperated based on `str.split`, where `n=1` indicates the string is split once. We create two new attributes in the original data frame, `City_clean` and `Suburb`. Then we drop the old `City` city column and rename our new `City` attribute.

# %%
# creates a new data frame that splits the values in the orginal data frame on the '-' character 
newdf = df["City"].str.split('-', n = 1, expand = True) 
newdf.head()

# creates two new columns 
df['City_clean'] = newdf[0]
df['Suburb'] = newdf[1]

# removes the old column
df.drop(["City"], axis = 1, inplace = True) 

# renames as 'City'
df.rename(index=str, columns={"City_clean": "City"});

# %%
df.ix[16:30,['Suburb']]
# Out:
#                          Suburb
# 16                         None
# 17                      Dundalk
# 18                         None
# 19                 Metropolitan
# 20                         None
# 21                 Metropolitan
# 22                         None
# 23                  Sub. Burton
# 24   Sub. Mt. Washington Summit
# 25               Sub. Villahove
# 26           Sub. Colonial Park
# 27       Sub. Linthicum Heights
# 28                         None
# 29                         None
# 30                         None

# %% [markdown]
# The `BUILDINGS_Age` attribute represents the range of the age of the buildings in a region. Notice the range is given is given as a string of text. For purpose of analysis, we would like to extract the upper end of the range and create a column of numeric values.

# %%
df.ix[0:15,'BUILDINGS_Age']
# Out:
# 0      1 to 10 years
# 1           12 years
# 2      1 to 20 years
# 3           10 years
# 4      1 to 20 years
# 5                NaN
# 6           25 years
# 7     15 to 25 years
# 8           15 years
# 9      5 to 25 years
# 10          20 years
# 11     5 to 10 years
# 12          10 years
# 13          25 years
# 14     1 to 20 years
# 15     6 to 25 years
# Name: BUILDINGS_Age, dtype: object

# %% [markdown]
# Observe that the numeric value at the end of the range is always the last number followed by the string `years`. We use specific string patterns called __regular expressions (regex)__ and `str.extract()` to create a new attribute called `max_building_age`.

# %%
df['max_building_age'] = df['BUILDINGS_Age'].str.extract('(\d+)(?!.*\d)', expand=True)

# %% [markdown]
# The regular expression in this example is `(\d+)(?!.*\d)` and was tested using [Pythex](https://pythex.org/), a regex editor. We could have imported `re` , Python's regular expression library, to perform the same task, however this notebook consistenly uses `str()` functions.

# %%
df.ix[0:57,['BUILDINGS_Age','max_building_age']]
# Out:
#              BUILDINGS_Age max_building_age
# 0            1 to 10 years               10
# 1                 12 years               12
# 2            1 to 20 years               20
# 3                 10 years               10
# 4            1 to 20 years               20
# 5                      NaN              NaN
# 6                 25 years               25
# 7           15 to 25 years               25
# 8                 15 years               15
# 9            5 to 25 years               25
# 10                20 years               20
# 11           5 to 10 years               10
# 12                10 years               10
# 13                25 years               25
# 14           1 to 20 years               20
# 15           6 to 25 years               25
# 16                12 years               12
# 17                20 years               20
# 18                20 years               20
# 19           1 to 25 years               25
# 20                35 years               35
# 21                25 years               25
# 22           1 to 15 years               15
# 23          15 to 25 years               25
# 24          20 to 40 years               40
# 25                     NaN              NaN
# 26                     NaN              NaN
# 27                     NaN              NaN
# 28          35 to 50 years               50
# 29                20 years               20
# 30  Row 20, Frame 35 years               35
# 31                15 years               15
# 32                20 Years               20
# 33                25 years               25
# 34          40 to 60 years               60
# 35                15 years               15
# 36          25 to 45 years               45
# 37                15 years               15
# 38                40 years               40
# 39                35 years               35
# 40          40 to 50 years               50
# 41          35 to 50 years               50
# 42                     NaN              NaN
# 43                     NaN              NaN
# 44           1 to 30 years               30
# 45                     NaN              NaN
# 46                     NaN              NaN
# 47                     NaN              NaN
# 48                     NaN              NaN
# 49                     NaN              NaN
# 50                65 years               65
# 51                      60               60
# 52                50 years               50
# 53                60 years               60
# 54                35 years               35
# 55                60 years               60
# 56                60 years               60

# %% [markdown]
#  The `Date`, the date indicated on the form, has three attributes with the pattern given by **month day, year**. As previously stated, we would like to have a single attribute per column.

# %%
df.ix[0:3,['Date']]
# Out:
#          Date
# 0  May 4,1937
# 1  May 4,1937
# 2  May 4,1937
# 3  May 4,1937

# %% [markdown]
# We can seperate this column into three columns:  `Month`, `Day`, and `Year` using `str.extract()` and regex patterns
# `(\d\d\d\d)` to indicate four digit year, `(\d)` to indicate a single digit day, and ` [A-Z]\w{0,}` to indicate __aplhanumeric__ text to extract the month. Note that regex can also be used to reformat the date column.

# %%
# extracts the year 
df['Year'] = df['Date'].str.extract('(\d\d\d\d)', expand=True)

# extracts day  
df['Day'] = df['Date'].str.extract('(\d)', expand=True)

# extracts month 
df['Month'] = df['Date'].str.extract('([A-Z]\w{0,})', expand=True)

df.ix[0:3,['Date','Month','Day','Year']]
# Out:
#          Date Month Day  Year
# 0  May 4,1937   May   4  1937
# 1  May 4,1937   May   4  1937
# 2  May 4,1937   May   4  1937
# 3  May 4,1937   May   4  1937

# %% [markdown]
# Similar to `BUILDINGS_Age`, `INHABITANTS_Annual_Income`, the range of income of residents in a section, is a string of text and we would like to extract the numeric value at the end of the range.

# %%
df.ix[0:7,['INHABITANTS_Annual_Income']]
# Out:
#   INHABITANTS_Annual_Income
# 0             $3000 - 5,000
# 1                over $5000
# 2               3500 - 7000
# 3                over $5000
# 4          $3,500 - $10,000
# 5                       NaN
# 6                over $4000
# 7                over $5000

# %% [markdown]
# Observe that some values are located after '$', some inlcude '-', and others include ','.Since the pattern to extract the last numeric value varies, we use `str.replace()`, `str.extract`, and regex in a sequence of operations to create a new column `max_annual_income`.

# %%
# replaces anything that is not a digit or ',' with empty space
df['max_annual_income'] = df['INHABITANTS_Annual_Income'].str.replace('[^\d(,)]',' ')

# %%
df.ix[0:7,['max_annual_income']]
# Out:
#   max_annual_income
# 0      3000   5,000
# 1              5000
# 2       3500   7000
# 3              5000
# 4   3,500    10,000
# 5               NaN
# 6              4000
# 7              5000

# %% [markdown]
# We did not include the delimeter in the previous `str.replace()` operation because their positions would have been replaced by an empty space. Now we want to remove delimeters.

# %%
# removes delimeter by replacing ',' with ''
df['max_annual_income'] = df['max_annual_income'].str.replace('[(,)]','')

# %%
df.ix[0:7,['max_annual_income']]
# Out:
#   max_annual_income
# 0       3000   5000
# 1              5000
# 2       3500   7000
# 3              5000
# 4     3500    10000
# 5               NaN
# 6              4000
# 7              5000

# %% [markdown]
# Finally, we can extract the last number.

# %%
# extracts the second or last number 
df['max_annual_income'] = df['max_annual_income'].str.extract('(\d+)(?!.*\d)', expand=True)

# %%
df.ix[0:7,['max_annual_income']]
# Out:
#   max_annual_income
# 0              5000
# 1              5000
# 2              7000
# 3              5000
# 4             10000
# 5               NaN
# 6              4000
# 7              5000

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# Some aspects of __data manipulation__, altering data to make it easier to read or use, include sorting and grouping attributes and encoding categorical variables.

# %% [markdown]
# ### Sorting and Grouping

# %% [markdown]
# The values of `Area_Number` are out of order and we want these values to be sorted by `Security_Grade`.

# %%
# removes any additional spaces from Security_Grade
df['Security_Grade'] = df['Security_Grade'].str.replace('[\W]','')
# converts 'Area_Number' from type object to type 'numeric'
df['Area_Number'] = pd.to_numeric(df['Area_Number'])
df.ix[0:10,['Security_Grade','Area_Number']]
# Out:
#    Security_Grade  Area_Number
# 0               A            2
# 1               A            1
# 2               A            3
# 3               A            4
# 4               A            5
# 5               A            6
# 6               B            1
# 7               B            2
# 8               B            3
# 9               B            4
# 10              B            5

# %% [markdown]
# To do this, we created use the `sort_values()` function on the original data frame and reset the index. First, the data is sorted and grouped by `Security_Grade` and then `Area_Number` is sorted in increasing order.

# %%
df = df.sort_values(by=['Security_Grade', 'Area_Number'])
# resets the index starting from 0
df = df.reset_index(drop=True)
df.ix[0:10,['Security_Grade','Area_Number']]
# Out:
#    Security_Grade  Area_Number
# 0               A            1
# 1               A            2
# 2               A            3
# 3               A            4
# 4               A            5
# 5               A            6
# 6               B            1
# 7               B            2
# 8               B            3
# 9               B            4
# 10              B            5

# %% [markdown]
# ### Encoding Categorical Data

# %%
 df.ix[0:15,'INHABITANTS_Population_Increase']
# Out:
# 0     Moderately fast
# 1               Fast
# 2     Moderately fast
# 3              Slowly
# 4     Moderately fast
# 5                 NaN
# 6                 NaN
# 7              Slowly
# 8     Moderately fast
# 9     Moderately fast
# 10                NaN
# 11             Slowly
# 12             Slowly
# 13         Moderately
# 14             Slowly
# 15              Fast
# Name: INHABITANTS_Population_Increase, dtype: object

# %%
 df.ix[0:15,'Terrain_Description']
# Out:
# 0          Undulating
# 1              Rolling
# 2              Rolling
# 3                Level
# 4          Undulating
# 5              Rolling
# 6     Rolling to hilly
# 7     Rolling to hilly
# 8           High level
# 9     Rolling to level
# 10         Undulating
# 11             Rolling
# 12          High level
# 13             Rolling
# 14         Undulating
# 15        Rolling high
# Name: Terrain_Description, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %% [markdown]
# The goal of __exploratory data analysis (EDA)__ is to explore attributes across multiple entities to decide what statistical or machine learning techniques to apply to the data. Visualizations are used to assist in understanding the data.

# %% [markdown]
# The `.describe()` function summarizes a data frame column. Since the data type of `max_building_age` is currently type 'object', which in python is an indcator of type 'string', we have to first convert this attribute into a numeric value.

# %%
df['max_building_age'].describe()
# Out:
# count     46
# unique    12
# top       25
# freq       9
# Name: max_building_age, dtype: object

# %% [markdown]
# Now that `max_building_age` is numeric type, we see that `describe()` provides __summary statistics__ on this attribute.

# %%
# converts max_building age to numeric type
df["max_building_age"] = pd.to_numeric(df["max_building_age"])
df['max_building_age'].describe()
# Out:
# count    46.000000
# mean     30.086957
# std      16.497577
# min      10.000000
# 25%      20.000000
# 50%      25.000000
# 75%      40.000000
# max      65.000000
# Name: max_building_age, dtype: float64

# %% [markdown]
# We can the same operations to `max_annual_income`.

# %%
df['max_annual_income'].describe()
# Out:
# count       46
# unique      12
# top       2500
# freq         8
# Name: max_annual_income, dtype: object

# %%
df['max_annual_income'] = pd.to_numeric(df['max_annual_income'])
df['max_annual_income'].describe()
# Out:
# count       46.000000
# mean      3139.130435
# std       2009.806874
# min       1000.000000
# 25%       1850.000000
# 50%       2750.000000
# 75%       4000.000000
# max      10000.000000
# Name: max_annual_income, dtype: float64

# %% [markdown]
# Finally we create some plots our data. A __scatter plot__ and a __bar chart__ are shown below.

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter',x='max_building_age',y='max_annual_income',color='red', title='max_annual income vs. max_building age')
plt.show()

# %%
df.groupby('Security_Grade')['max_annual_income'].nunique().plot(kind='bar', title='Max Annual Income by Security_Grade')
plt.show()

# %%
# %%HTML
# <script type='text/javascript' src='https://10ay.online.tableau.com/javascripts/api/viz_v1.js'></script><div class='tableauPlaceholder' style='width: 1920px; height: 895px;'><object class='tableauViz' width='1920' height='895' style='display:none;'><param name='host_url' value='https%3A%2F%2F10ay.online.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='&#47;t&#47;sadata' /><param name='name' value='mapping_inequality&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='showAppBanner' value='false' /><param name='filter' value='iframeSizedToWindow=true' /></object></div>
# Out:
# <script type='text/javascript' src='https://10ay.online.tableau.com/javascripts/api/viz_v1.js'></script><div class='tableauPlaceholder' style='width: 1920px; height: 895px;'><object class='tableauViz' width='1920' height='895' style='display:none;'><param name='host_url' value='https%3A%2F%2F10ay.online.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='&#47;t&#47;sadata' /><param name='name' value='mapping_inequality&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='showAppBanner' value='false' /><param name='filter' value='iframeSizedToWindow=true' /></object></div>

# %% [markdown]
# df.groupby('Security_Grade')['max_building_age'].nunique().plot(kind='bar', title='Max Building Age by Security_Grade')
# plt.show()
